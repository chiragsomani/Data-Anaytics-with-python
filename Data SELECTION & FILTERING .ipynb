# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon.csv')

# %%
df
# Out:
#                                              abilities  against_bug  \
# 0                          ['Overgrow', 'Chlorophyll']         1.00
# 1                          ['Overgrow', 'Chlorophyll']         1.00
# 2                          ['Overgrow', 'Chlorophyll']         1.00
# 3                             ['Blaze', 'Solar Power']         0.50
# 4                             ['Blaze', 'Solar Power']         0.50
# 5                             ['Blaze', 'Solar Power']         0.25
# 6                             ['Torrent', 'Rain Dish']         1.00
# 7                             ['Torrent', 'Rain Dish']         1.00
# 8                             ['Torrent', 'Rain Dish']         1.00
# 9                          ['Shield Dust', 'Run Away']         1.00
# 10                                       ['Shed Skin']         1.00
# 11                     ['Compoundeyes', 'Tinted Lens']         0.50
# 12                         ['Shield Dust', 'Run Away']         0.50
# ...

# %% [markdown]
# Quick Statistical analysis

# %%
df.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %% [markdown]
# Selecting any one coloum from df

# %%
df['speed']
# Out:
# 0       45
# 1       60
# 2       80
# 3       65
# 4       80
# 5      100
# 6       43
# 7       58
# 8       78
# 9       45
# 10      30
# 11      70
# 12      50
# 13      35
# 14     145
# 15      56
# 16      71
# 17     121
# 18      72
# 19      77
# 20      70
# 21     100
# 22      55
# 23      80
# 24      90
# 25     110
# 26      40
# 27      65
# 28      41
# 29      56
#       ...
# 771     59
# 772     95
# 773    120
# 774     65
# 775     36
# 776     96
# 777     96
# 778     92
# 779     36
# 780     40
# 781     45
# 782     65
# 783     85
# 784    130
# 785     95
# 786     75
# 787     85
# 788     37
# 789     37
# 790     97
# 791     97
# 792    103
# 793     79
# 794    151
# 795     83
# 796     61
# 797    109
# 798     43
# 799     79
# 800     65
# Name: speed, Length: 801, dtype: int64

# %%
df[['speed']] ##gives a df
# Out:
#      speed
# 0       45
# 1       60
# 2       80
# 3       65
# 4       80
# 5      100
# 6       43
# 7       58
# 8       78
# 9       45
# 10      30
# 11      70
# 12      50
# 13      35
# 14     145
# 15      56
# 16      71
# 17     121
# 18      72
# 19      77
# 20      70
# 21     100
# 22      55
# 23      80
# 24      90
# 25     110
# 26      40
# 27      65
# 28      41
# 29      56
# ..     ...
# 771     59
# 772     95
# 773    120
# 774     65
# 775     36
# 776     96
# 777     96
# 778     92
# 779     36
# 780     40
# 781     45
# 782     65
# 783     85
# 784    130
# 785     95
# 786     75
# 787     85
# 788     37
# 789     37
# 790     97
# 791     97
# 792    103
# 793     79
# 794    151
# 795     83
# 796     61
# 797    109
# 798     43
# 799     79
# 800     65
#
# [801 rows x 1 columns]

# %%
##calling multpile column implies returing df 
df[['speed', 'generation']]
# Out:
#      speed  generation
# 0       45           1
# 1       60           1
# 2       80           1
# 3       65           1
# 4       80           1
# 5      100           1
# 6       43           1
# 7       58           1
# 8       78           1
# 9       45           1
# 10      30           1
# 11      70           1
# 12      50           1
# 13      35           1
# 14     145           1
# 15      56           1
# 16      71           1
# 17     121           1
# 18      72           1
# 19      77           1
# 20      70           1
# 21     100           1
# 22      55           1
# 23      80           1
# 24      90           1
# 25     110           1
# 26      40           1
# 27      65           1
# 28      41           1
# 29      56           1
# ..     ...         ...
# 771     59           7
# 772     95           7
# 773    120           7
# 774     65           7
# 775     36           7
# 776     96           7
# 777     96           7
# 778     92           7
# ...

# %%
df[0:10] ##retriving rows
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 5     ['Blaze', 'Solar Power']         0.25           1.0             1.0
# 6     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 7     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 8     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 9  ['Shield Dust', 'Run Away']         1.00           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# ...

# %%
## retriving columns from loc iloc function
## loc reads label while iloc reads index or position
var1_df = df.loc[0:10]
var2_df = df.iloc[0:10]
var1_df.tail()
# Out:
#                       abilities  against_bug  against_dark  against_dragon  \
# 6      ['Torrent', 'Rain Dish']          1.0           1.0             1.0
# 7      ['Torrent', 'Rain Dish']          1.0           1.0             1.0
# 8      ['Torrent', 'Rain Dish']          1.0           1.0             1.0
# 9   ['Shield Dust', 'Run Away']          1.0           1.0             1.0
# 10                ['Shed Skin']          1.0           1.0             1.0
#
#     against_electric  against_fairy  against_fight  against_fire  \
# 6                2.0            1.0            1.0           0.5
# 7                2.0            1.0            1.0           0.5
# 8                2.0            1.0            1.0           0.5
# 9                1.0            1.0            0.5           2.0
# 10               1.0            1.0            0.5           2.0
#
#     against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
var2_df.tail()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 5     ['Blaze', 'Solar Power']         0.25           1.0             1.0
# 6     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 7     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 8     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 9  ['Shield Dust', 'Run Away']         1.00           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 5               2.0            0.5            0.5           0.5
# 6               2.0            1.0            1.0           0.5
# 7               2.0            1.0            1.0           0.5
# 8               2.0            1.0            1.0           0.5
# 9               1.0            1.0            0.5           2.0
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %% [markdown]
# filtering rows and column both from iloc

# %%
df.iloc[0:10, 7:9] ##row range, column range
# Out:
#    against_fire  against_flying
# 0           2.0             2.0
# 1           2.0             2.0
# 2           2.0             2.0
# 3           0.5             1.0
# 4           0.5             1.0
# 5           0.5             1.0
# 6           0.5             1.0
# 7           0.5             1.0
# 8           0.5             1.0
# 9           2.0             2.0

# %% [markdown]
# loc uses label

# %%
df.loc[0:5,'speed'] ##label
# Out:
# 0     45
# 1     60
# 2     80
# 3     65
# 4     80
# 5    100
# Name: speed, dtype: int64

# %%
df.iloc[0:5, [-6]] ##integer positioning, retriving rows and columns with their index not label
# Out:
#    speed
# 0     45
# 1     60
# 2     80
# 3     65
# 4     80

# %%
var = df['speed'] > 100 #3return series with value for each and every row

# %%
## to get data frame
var_df = df[df['speed'] > 100]
var_df
# Out:
#                                              abilities  against_bug  \
# 14                                 ['Swarm', 'Sniper']         0.50
# 17           ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50
# 25          ['Static', 'Lightningrod', 'Surge Surfer']         1.00
# 37   ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...         0.50
# 50   ['Sand Veil', 'Arena Trap', 'Sand Force', 'San...         1.00
# 52   ['Limber', 'Technician', 'Unnerve', 'Fur Coat'...         1.00
# 63       ['Synchronize', 'Inner Focus', 'Magic Guard']         2.00
# 64       ['Synchronize', 'Inner Focus', 'Magic Guard']         2.00
# 77            ['Run Away', 'Flash Fire', 'Flame Body']         0.50
# 84          ['Run Away', 'Early Bird', 'Tangled Feet']         0.50
# 93                                     ['Cursed Body']         0.25
# 100              ['Soundproof', 'Static', 'Aftermath']         1.00
# 120         ['Illuminate', 'Natural Cure', 'Analytic']         2.00
# ...

# %% [markdown]
# Multiple Filters

# %%
var_ser =  (df['speed'] > 100) & (df['generation'] == 1)

# %%
var_df = df[(df['speed'] > 100) & (df['generation'] == 1)]
var_df[['speed', 'generation']]
# Out:
#      speed  generation
# 14     145           1
# 17     121           1
# 25     110           1
# 37     109           1
# 50     110           1
# 52     115           1
# 63     105           1
# 64     150           1
# 77     105           1
# 84     110           1
# 93     130           1
# 100    150           1
# 120    115           1
# 122    105           1
# 124    105           1
# 126    105           1
# 127    110           1
# 134    130           1
# 141    150           1
# 149    140           1
